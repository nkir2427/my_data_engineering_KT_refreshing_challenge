# %% [markdown]
# In LinkedList class that we implemented in our tutorial add following two methods,
#
#
# def insert_after_value(self, data_after, data_to_insert):
#     # Search for first occurance of data_after value in linked list
#     # Now insert data_to_insert after data_after node
#
# def remove_by_value(self, data):
#     # Remove first node that contains data
#
# Now make following calls,
#
#     ll = LinkedList()
#     ll.insert_values(["banana","mango","grapes","orange"])
#     ll.print()
#     ll.insert_after_value("mango","apple") # insert apple after mango
#     ll.print()
#     ll.remove_by_value("orange") # remove orange from linked list
#     ll.print()
#     ll.remove_by_value("figs")
#     ll.print()
#     ll.remove_by_value("banana")
#     ll.remove_by_value("mango")
#     ll.remove_by_value("apple")
#     ll.remove_by_value("grapes")
#     ll.print()

# %% [markdown]
# ## 3. Insert and Remove Nodes by Value
#
# Extend the existing `LinkedList` class by implementing the following two methods.
#
# ### 1. `insert_after_value(data_after, data_to_insert)`
#
# Search for the **first occurrence** of `data_after` in the linked list and insert a new node containing `data_to_insert` **immediately after** it.
#
# ```python
# def insert_after_value(self, data_after, data_to_insert):
#     # Search for the first occurrence of data_after
#     # Insert data_to_insert immediately after the matching node
# ```
#
# ---
#
# ### 2. `remove_by_value(data)`
#
# Search for the **first node** containing the specified value and remove it from the linked list.
#
# ```python
# def remove_by_value(self, data):
#     # Remove the first node that contains the specified data
# ```
#
# ---
#
# ## Example
#
# Create a linked list with the following values:
#
# ```python
# ll = LinkedList()
# ll.insert_values(["banana", "mango", "grapes", "orange"])
# ll.print()
# ```
#
# **Output**
#
# ```text
# banana --> mango --> grapes --> orange
# ```
#
# ---
#
# ### Insert `"apple"` after `"mango"`
#
# ```python
# ll.insert_after_value("mango", "apple")
# ll.print()
# ```
#
# **Output**
#
# ```text
# banana --> mango --> apple --> grapes --> orange
# ```
#
# ---
#
# ### Remove `"orange"`
#
# ```python
# ll.remove_by_value("orange")
# ll.print()
# ```
#
# **Output**
#
# ```text
# banana --> mango --> apple --> grapes
# ```
#
# ---
#
# ### Attempt to Remove `"figs"`
#
# Since `"figs"` is not present in the linked list, no changes should be made.
#
# ```python
# ll.remove_by_value("figs")
# ll.print()
# ```
#
# **Output**
#
# ```text
# banana --> mango --> apple --> grapes
# ```
#
# ---
#
# ### Remove All Remaining Nodes
#
# ```python
# ll.remove_by_value("banana")
# ll.remove_by_value("mango")
# ll.remove_by_value("apple")
# ll.remove_by_value("grapes")
# ll.print()
# ```
#
# **Output**
#
# ```text
# Linked list is empty
# ```
#
# ---
#
# ## Expected Learning Outcomes
#
# After completing this exercise, you should be able to:
#
# - Search for a node using its value.
# - Insert a new node after a specified node.
# - Remove the first occurrence of a node by value.
# - Handle cases where the target value does not exist.
# - Maintain the integrity of the linked list after insertion and deletion.

# %%
class Node:
    def __init__(self, data=None, next=None):
        self.data = data
        self.next = next

class LinkedList:
    def __init__(self):
        self.head = None

    def print(self):
        if self.head is None:
            print("Linked list is empty")
            return
        itr = self.head
        llstr = ''
        while itr:
            llstr += str(itr.data)+' --> ' if itr.next else str(itr.data)
            itr = itr.next
        print(llstr)

    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count+=1
            itr = itr.next

        return count

    def insert_at_begining(self, data):
        node = Node(data, self.head)
        self.head = node

        
    def insert_at_end(self, data):
        if self.head is None:
            self.head = Node(data, None)
            return

        itr = self.head

        while itr.next:
            itr = itr.next

        itr.next = Node(data, None)

    def insert_at(self, index, data):
        if index<0 or index>self.get_length():
            raise Exception("Invalid Index")

        if index==0:
            self.insert_at_begining(data)
            return

        count = 0
        itr = self.head
        while itr:
            if count == index - 1:
                node = Node(data, itr.next)
                itr.next = node
                break

            itr = itr.next
            count += 1

    def remove_at(self, index):
        if index<0 or index>=self.get_length():
            raise Exception("Invalid Index")

        if index==0:
            self.head = self.head.next
            return

        count = 0
        itr = self.head
        while itr:
            if count == index - 1:
                itr.next = itr.next.next
                break

            itr = itr.next
            count+=1

    def insert_values(self, data_list):
        self.head = None
        for data in data_list:
            self.insert_at_end(data)


    def insert_after_value(self, data_after, data_to_insert):
        count = 0
        itr =self.head
        #print(itr)
        while itr:
            if data_after==itr.data:
                node = Node(data_to_insert, itr.next)
                itr.next = node
                break
            itr = itr.next
            count += 1

            
        # Search for first occurance of data_after value in linked list
        # Now insert data_to_insert after data_after node

    def remove_by_value(self, data):
        
        count = 0
        itr =self.head
        #print(itr)
        while itr:
            if data==itr.data:
                #print(itr.data)
                #print(count-1)
                
                self.remove_at(count)
                return

            itr = itr.next
            count += 1
        print(f"{data} is not in the linked list")
        # Remove first node that contains data

# %%
 if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_values(["banana","mango","grapes","orange"])
    ll.print()
    ll.insert_after_value("mango","apple") # insert apple after mango
    ll.print()
    ll.remove_by_value("orange") # remove orange from linked list
    ll.print()
    ll.remove_by_value("figs")

    ll.remove_by_value("banana")
    ll.remove_by_value("mango")
    ll.remove_by_value("apple")
    ll.remove_by_value("grapes")
    ll.print()
# Out:
# banana --> mango --> grapes --> orange
# banana --> mango --> apple --> grapes --> orange
# banana --> mango --> apple --> grapes
# figs is not in the linked list
# Linked list is empty

# %%
        
if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_at_begining(5)
    ll.insert_at_begining(60)
    ll.print()
    ll.insert_values(["banana","mango","grapes","orange"])
    ll.insert_at(1,"blueberry")
    ll.remove_at(2)
    ll.print()

    ll.insert_values([45,7,12,567,99])
    ll.print() 
    ll.insert_at_end(67)
    ll.insert_at_end(99) 
    ll.print()

# %% [raw]
# ### 2.Implement doubly linked list. The only difference with regular linked list is that double linked has prev node reference as well. That way you can iterate in forward and backward direction. Your node class will look this this,
#
# class Node:
#     def __init__(self, data=None, next=None, prev=None):
#         self.data = data
#         self.next = next
#         self.prev = prev
#
# Add following new methods,
#
# def print_forward(self):
#     # This method prints list in forward direction. Use node.next
#
# def print_backward(self):
#     # Print linked list in reverse direction. Use node.prev for this.
#
#
# Implement all other methods in regular linked list class and make necessary changes for doubly linked list (you need to populate node.prev in all those methods)

# %% [markdown]
# ### 2. Implement Doubly Linked List
#
# A **Doubly Linked List** is similar to a **Singly Linked List**, but each node contains an additional reference to the **previous (`prev`) node**. This allows the list to be traversed in both the **forward** and **backward** directions.
#
# Your `Node` class should be defined as follows:
#
# ```python
# class Node:
#     def __init__(self, data=None, next=None, prev=None):
#         self.data = data
#         self.next = next
#         self.prev = prev
# ```
#
# ### Add the Following Methods
#
# #### `print_forward(self)`
#
# Print all elements of the linked list from **head to tail** using the `next` pointer.
#
# ```python
# def print_forward(self):
#     # This method prints the linked list in the forward direction.
#     # Traverse using node.next.
# ```
#
# #### `print_backward(self)`
#
# Print all elements of the linked list from **tail to head** using the `prev` pointer.
#
# ```python
# def print_backward(self):
#     # This method prints the linked list in the backward direction.
#     # Traverse using node.prev.
# ```
#
# ### Other Required Methods
#
# Implement all methods available in the regular linked list and update them to support a **Doubly Linked List** by maintaining both the `next` and `prev` pointers.
#
# The implementation should include the following methods:
#
# - `insert_at_beginning(data)`
# - `insert_at_end(data)`
# - `insert_at(index, data)`
# - `remove_at(index)`
# - `insert_values(data_list)`
# - `get_length()`
# - `print_forward()`
# - `print_backward()`
#
# > **Note:** Whenever a node is inserted or removed, make sure to update **both** the `next` and `prev` references to maintain the integrity of the doubly linked list.

# %%
class Node:
    def __init__(self, data=None, next=None, prev=None):
        self.data = data
        self.next = next
        self.prev = prev

class doubleLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
    
    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count+=1
            itr = itr.next

        return count

 #   def print_forward(self):
 #       itr = self.head

#        while itr:
#            print(
 #               f"Current: {id(itr)} | "
 #               f"Data: {itr.data} | "
 ##               f"Prev: {id(itr.prev) if itr.prev else None} | "
 #               f"Next: {id(itr.next) if itr.next else None}"
 #           )
 #           itr = itr.next  
  

    def print_forward(self):
        if self.head is None:
            print("Linked list is empty")
            return
        itr = self.head
        llstr = ''
        while itr:
            llstr += str(itr.data)+' <--> ' if itr.next else str(itr.data)
            itr = itr.next
        print(llstr)  
    # This method prints list in forward direction. Use node.next

    def print_backward(self):
        
        if self.head is None:
            print("Linked list is empty")
            return
            
        itr = self.head
        #print(itr)
        while itr.next:
            itr = itr.next

        
        llstr = ''
        
        while itr:
            llstr += str(itr.data)+' <--> ' if itr.prev else str(itr.data)
            itr = itr.prev
        print(llstr)  


    
    # Print linked list in reverse direction. Use node.prev for this.

    def insert_at_end(self, data):

        new_node = Node(data)

        if self.head is None:
            self.head = new_node
            return

        itr = self.head

        while itr.next:
            itr = itr.next

        itr.next = new_node
        new_node.prev = itr

   
    def insert_at_begining(self, data):
        node = Node(data, self.head)
        self.head = node        

    def insert_values(self, data_list):
        self.head = None
        for data in data_list:
            self.insert_at_end(data)


    def insert_after_value(self, data_after, data_to_insert):
        
        new_node = Node(data_to_insert)
        count = 0
        itr =self.head
        #print(itr)
        while itr:
            if data_after==itr.data:
                node = Node(data_to_insert, itr.next)
                next_node = itr.next
                # Connect new node
                new_node.prev = itr
                new_node.next = next_node
    
                # Connect previous node to new node
                itr.next = new_node
    
                # Connect next node back to new node
                if next_node:
                    next_node.prev = new_node
    
                return
    

            itr = itr.next
            count += 1

    def remove_by_value(self, data):
        
        count = 0
        itr =self.head
        #print(itr)
        while itr:
            if data==itr.data:
                #print(itr.data)
                #print(count-1)
                
                self.remove_at(count)
                return

            itr = itr.next
            count += 1
        print(f"{data} is not in the linked list")
        # Remove first node that contains data

          

    def insert_at(self, index, data):
        if index < 0 or index > self.get_length():
            raise Exception("Invalid Index")
    
        if index == 0:
            self.insert_at_begining(data)
            return
    
        new_node = Node(data)
    
        count = 0
        itr = self.head
    
        while itr:
            if count == index - 1:
                # Save the node currently after itr
                next_node = itr.next
    
                # Connect new node
                new_node.prev = itr
                new_node.next = next_node
    
                # Connect previous node to new node
                itr.next = new_node
    
                # Connect next node back to new node
                if next_node:
                    next_node.prev = new_node
    
                return
    
            itr = itr.next
            count += 1

    def remove_at(self, index):
        if index<0 or index>=self.get_length():
            raise Exception("Invalid Index")

        if index==0:
            self.head = self.head.next
            return

        count = 0
        itr = self.head
        while itr:
            if count == index - 1:
                itr.next = itr.next.next
                next_node = itr.next
                next_node.prev=itr
                #itr.next = itr.next.next
                break

            itr = itr.next
            count+=1




if __name__ == '__main__':
    ll = doubleLinkedList()
    ll.insert_values(["banana","mango","grapes","orange"])
    ll.insert_at_begining("blueberry")
    ll.insert_at_end("rambutan")
    ll.insert_at(2,"pineapple")

    ll.print_forward()
    ll.remove_at(2)
  
    ll.print_forward()
    
    ll.print_backward()
    ll.insert_after_value("mango","apple") # insert apple after mango
    ll.print_forward()
    
    ll.print_backward()

    ll.remove_by_value("figs")

    ll.remove_by_value("grapes")
  
    ll.print_forward()
    
    ll.print_backward()
    #ll.insert_values([45,7,12,567,99])
    #ll.insert_at_end(67)
    #ll.print()
# Out:
# blueberry <--> banana <--> pineapple <--> mango <--> grapes <--> orange <--> rambutan
# blueberry <--> banana <--> mango <--> grapes <--> orange <--> rambutan
# rambutan <--> orange <--> grapes <--> mango <--> banana
# blueberry <--> banana <--> mango <--> apple <--> grapes <--> orange <--> rambutan
# rambutan <--> orange <--> grapes <--> apple <--> mango <--> banana
# figs is not in the linked list
# blueberry <--> banana <--> mango <--> apple <--> orange <--> rambutan
# rambutan <--> orange <--> apple <--> mango <--> banana
